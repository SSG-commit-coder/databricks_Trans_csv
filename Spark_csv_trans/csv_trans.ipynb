# %%
#### Dataframe
data =[
    (1,'Shiv',40),
    (2,'Ravi',30),
    (3,'Kiran',35)
]

col =["id","name","age"]

df = spark.createDataFrame(data, col)
df.show

# %%
df.printSchema()

# %% [markdown]
# ## Show records

# %%
df.display ()
